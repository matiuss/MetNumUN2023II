# %% [markdown]
# <a href="https://colab.research.google.com/github/matiuss/MetNumUN2023II/blob/main/Lab3/dfmateusvcognitiveclassaapplieddatasciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LinkedIn:http://linkedin.com/in/daniel-fernando-mateus-vega-465043139
#
# ![Screenshot 2023-11-15 160857.png](data:image/png;base64,...)
